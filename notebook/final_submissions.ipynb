# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import Model, Sequential
from keras.layers import Input, Dense
from keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Loading data

# %%
train = pd.read_csv(r"../data/train.csv")
test = pd.read_csv(r"../data/test.csv")

train.columns = [col.strip().lower() for col in train.columns]
test.columns = [col.strip().lower() for col in test.columns]

# %% [markdown]
# ### Submission 1: Autoencoders

# %%
X_train = train.drop(['class'], axis=1)
y_train = train['class']

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(test)

X_train_non_fraud = X_train_scaled[y_train == 0]

# %%
input_dim = X_train_non_fraud.shape[1]
encoding_dim = 14

input_layer = Input(shape=(input_dim,))
encoder = Dense(encoding_dim, activation="tanh")(input_layer)
encoder = Dense(int(encoding_dim / 2), activation="relu")(encoder)
decoder = Dense(int(encoding_dim / 2), activation='tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)

autoencoder = Model(inputs=input_layer, outputs=decoder)
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

autoencoder.fit(X_train_non_fraud, X_train_non_fraud,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_split=0.2,
                verbose=1)
# Out:
# Epoch 1/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - loss: 0.8680 - val_loss: 1.0224
# Epoch 2/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.7445 - val_loss: 0.9818
# Epoch 3/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.7136 - val_loss: 0.9593
# Epoch 4/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.6956 - val_loss: 0.9419
# Epoch 5/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6832 - val_loss: 0.9322
# Epoch 6/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.6992 - val_loss: 0.9280
# Epoch 7/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6774 - val_loss: 0.9244
# Epoch 8/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6701 - val_loss: 0.9194
# Epoch 9/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6719 - val_loss: 0.9151
# Epoch 10/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6485 - val_loss: 0.9133
# Epoch 11/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6449 - val_loss: 0.9100
# Epoch 12/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6596 - val_loss: 0.9064
# Epoch 13/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6552 - val_loss: 0.9085
# Epoch 14/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.6500 - val_loss: 0.9077
# Epoch 15/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.6596 - val_loss: 0.9092
# Epoch 16/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.6432 - val_loss: 0.9057
# Epoch 17/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6473 - val_loss: 0.9051
# Epoch 18/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6482 - val_loss: 0.9039
# Epoch 19/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6421 - val_loss: 0.9010
# Epoch 20/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6466 - val_loss: 0.8993
# Epoch 21/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6466 - val_loss: 0.8977
# Epoch 22/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6351 - val_loss: 0.8974
# Epoch 23/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6415 - val_loss: 0.8974
# Epoch 24/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6362 - val_loss: 0.8961
# Epoch 25/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6619 - val_loss: 0.8968
# Epoch 26/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6447 - val_loss: 0.8956
# Epoch 27/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6467 - val_loss: 0.8939
# Epoch 28/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.6417 - val_loss: 0.8949
# Epoch 29/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.6276 - val_loss: 0.8946
# Epoch 30/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6444 - val_loss: 0.8969
# Epoch 31/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6403 - val_loss: 0.8952
# Epoch 32/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6358 - val_loss: 0.8964
# Epoch 33/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6316 - val_loss: 0.8975
# Epoch 34/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.6242 - val_loss: 0.8946
# Epoch 35/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.6186 - val_loss: 0.8968
# Epoch 36/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.6310 - val_loss: 0.8974
# Epoch 37/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 0.6342 - val_loss: 0.8978
# Epoch 38/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6369 - val_loss: 0.8943
# Epoch 39/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.6319 - val_loss: 0.8954
# Epoch 40/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6280 - val_loss: 0.8984
# Epoch 41/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6236 - val_loss: 0.8966
# Epoch 42/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.6336 - val_loss: 0.8986
# Epoch 43/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6293 - val_loss: 0.8991
# Epoch 44/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.6429 - val_loss: 0.8989
# Epoch 45/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6233 - val_loss: 0.8982
# Epoch 46/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6139 - val_loss: 0.8989
# Epoch 47/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.6296 - val_loss: 0.9005
# Epoch 48/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6340 - val_loss: 0.9000
# Epoch 49/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.6174 - val_loss: 0.8981
# Epoch 50/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.6175 - val_loss: 0.8994
# Epoch 51/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.6135 - val_loss: 0.9051
# Epoch 52/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6223 - val_loss: 0.8992
# Epoch 53/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6136 - val_loss: 0.8988
# Epoch 54/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6240 - val_loss: 0.9000
# Epoch 55/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6193 - val_loss: 0.9007
# Epoch 56/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6330 - val_loss: 0.9020
# Epoch 57/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6310 - val_loss: 0.9028
# Epoch 58/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6201 - val_loss: 0.9010
# Epoch 59/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6249 - val_loss: 0.9013
# Epoch 60/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6237 - val_loss: 0.9015
# Epoch 61/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.6265 - val_loss: 0.9031
# Epoch 62/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.6359 - val_loss: 0.9027
# Epoch 63/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6152 - val_loss: 0.9016
# Epoch 64/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.6468 - val_loss: 0.9022
# Epoch 65/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.6250 - val_loss: 0.8997
# Epoch 66/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 0.6335 - val_loss: 0.9020
# Epoch 67/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.6180 - val_loss: 0.9015
# Epoch 68/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.6230 - val_loss: 0.9024
# Epoch 69/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.6197 - val_loss: 0.9025
# Epoch 70/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6191 - val_loss: 0.9010
# Epoch 71/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6211 - val_loss: 0.9037
# Epoch 72/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.6209 - val_loss: 0.9013
# Epoch 73/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.6334 - val_loss: 0.9036
# Epoch 74/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6128 - val_loss: 0.9012
# Epoch 75/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6194 - val_loss: 0.8994
# Epoch 76/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6173 - val_loss: 0.8997
# Epoch 77/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6257 - val_loss: 0.9026
# Epoch 78/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6142 - val_loss: 0.9059
# Epoch 79/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6212 - val_loss: 0.9001
# Epoch 80/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6140 - val_loss: 0.8965
# Epoch 81/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.6185 - val_loss: 0.8986
# Epoch 82/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.6270 - val_loss: 0.9015
# Epoch 83/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.6341 - val_loss: 0.8986
# Epoch 84/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.6233 - val_loss: 0.8963
# Epoch 85/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.6277 - val_loss: 0.8983
# Epoch 86/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.6169 - val_loss: 0.8968
# Epoch 87/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6189 - val_loss: 0.9002
# Epoch 88/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6178 - val_loss: 0.8965
# Epoch 89/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.6234 - val_loss: 0.9016
# Epoch 90/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6298 - val_loss: 0.8997
# Epoch 91/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.6261 - val_loss: 0.8981
# Epoch 92/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.6163 - val_loss: 0.9006
# Epoch 93/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.6268 - val_loss: 0.9015
# Epoch 94/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.6251 - val_loss: 0.9000
# Epoch 95/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.6052 - val_loss: 0.9038
# Epoch 96/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.6211 - val_loss: 0.8967
# Epoch 97/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.6195 - val_loss: 0.8970
# Epoch 98/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.6120 - val_loss: 0.8974
# Epoch 99/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.6228 - val_loss: 0.8990
# Epoch 100/100
# 533/533 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.6173 - val_loss: 0.8958

# %%
test_pred = autoencoder.predict(X_test_scaled)
mse_test = np.mean(np.power(X_test_scaled - test_pred, 2), axis=1)

mse_min, mse_max = mse_test.min(), mse_test.max()
fraud_prob = (mse_test - mse_min) / (mse_max - mse_min)
# Out:
# 3561/3561 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step

# %%
test['Class'] = fraud_prob.round(2)
submission = test[['id', 'Class']]
submission.to_csv(r"../data/submission_with_autoencoder.csv", index=False)

# %% [markdown]
# ### Submission 2: Random Forest Classifier (with best parameters)

# %%
test = pd.read_csv(r"../data/test.csv")
test.columns = [col.strip().lower() for col in test.columns]

X = train.drop('class', axis=1)
y = train['class']

# %% [markdown]
# #### Submission 2.1. RFC {max_depth=10, n_estimators=100, random_state=42}

# %%
clf1 = RandomForestClassifier(max_depth=10, n_estimators=100, random_state=42)
clf1.fit(X, y)

sub1 = test.copy(deep=True)
submission_prob = clf1.predict_proba(sub1)[:, 1]
sub1['Class'] = submission_prob.round(2)
submission1 = sub1[['id','Class']]
submission1.to_csv(r"../data/second_iteration_submission1.csv",index=False)

# %% [markdown]
# #### Submission 2.2. RFC {class_weight='balanced', max_depth=10, n_estimators=100, random_state=42}

# %%
clf2 = RandomForestClassifier(class_weight='balanced', max_depth=10, n_estimators=100, random_state=42)
clf2.fit(X, y)

sub2 = test.copy(deep=True)
submission_prob = clf2.predict_proba(sub2)[:, 1]
sub2['Class'] = submission_prob.round(2)
submission2 = sub2[['id','Class']]
submission2.to_csv(r"../data/second_iteration_submission2.csv",index=False)

# %% [markdown]
# #### Submission 2.3. RFC {class_weight='balanced', max_depth=10, n_estimators=200, random_state=42}

# %%
clf3 = RandomForestClassifier(class_weight='balanced', max_depth=10, n_estimators=200, random_state=42)
clf3.fit(X, y)

sub3 = test.copy(deep=True)
submission_prob = clf3.predict_proba(sub3)[:, 1]
sub3['Class'] = submission_prob.round(2)
submission3 = sub3[['id','Class']]
submission3.to_csv(r"../data/second_iteration_submission3.csv",index=False)

# %% [markdown]
# ### Submission 3: Random Forest Classifier (with oversampling the unbalanced data using SMOTE)

# %%
X = train.drop('class', axis=1)
y = train['class']

smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

print(pd.Series(y_resampled).value_counts())
# Out:
# class
# 0    170523
# 1    170523
# Name: count, dtype: int64

# %%
rf = RandomForestClassifier(random_state=42, 
                            max_depth=10,
                            min_samples_leaf=4,
                            min_samples_split=10,
                            n_estimators=100)

rf.fit(X_resampled, y_resampled)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=4, min_samples_split=10,
#                        random_state=42)

# %%
test = pd.read_csv(r"../data/test.csv")
test.columns = [col.strip().lower() for col in test.columns]

submission_prob = rf.predict_proba(test)[:, 1]
test['Class'] = submission_prob.round(1)
submission = test[['id','Class']]
submission.to_csv(r"../data/submission_with_smote.csv",index=False)
